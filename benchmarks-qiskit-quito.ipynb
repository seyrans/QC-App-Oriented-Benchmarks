# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
min_qubits=2
max_qubits=5
max_circuits=1
num_shots=100

backend_id="ibmq_quito"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = None

# # *** If using IBMQ hardware, run this once to authenticate
from qiskit import IBMQ
IBMQ.save_account('5464069b135d4041f4ec13a114d3ae2823750767f3ef1c33259bc7719449313fd51a84b7e3393f0bed4757c595a38087403cfdd8938409fe1aeb899b97710f99',overwrite=True)

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"
# group="YOUR_GROUP_NAME"
# project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify the backend using a known "backend_id"
# # Use 'sabre' layout for IBM backends
exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre' }
# backend_id="ibmq_belem"

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # *** Use these lines when running on hardware backend, to limit use of resources
# min_qubits=2
# max_qubits=5
# max_circuits=1
# num_shots=100

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Add Qiskit pass manager as a custom 'transformer' method
# import _common.transformers.qiskit_passmgr as qiskit_passmgr
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre', "transformer": qiskit_passmgr.do_transform }

# # Example of TrueQ Randomized Compilation
# import _common.transformers.trueq_rc as trueq_rc
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre', "transformer": trueq_rc.local_rc } 

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options = { "noise_model": custom_qiskit_noise_model.my_noise_model() }

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 19:36:32 UTC
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# WARNING: requested shots not equal to actual shots: 100 != 3
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 5, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 5, 0, 0
# Average Creation Time for the 3 qubit group = 0.001 secs
# Average Elapsed Time for the 3 qubit group = 2891.536 secs
# Average Execution Time for the 3 qubit group = 3.596 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.433, 1.041, 6.618 secs
# Average Fidelity for the 3 qubit group = 0.111
# Average Hellinger Fidelity for the 3 qubit group = 0.333
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 6, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0, 0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 2896.86 secs
# Average Execution Time for the 4 qubit group = 3.848 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.729, 1.171, 11.085 secs
# Average Fidelity for the 4 qubit group = 0.909
# Average Hellinger Fidelity for the 4 qubit group = 0.92
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 5, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 5, 0, 0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 2905.502 secs
# Average Execution Time for the 5 qubit group = 4.537 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.968, 1.269, 15.489 secs
# Average Fidelity for the 5 qubit group = 0.936
# Average Hellinger Fidelity for the 5 qubit group = 0.94
#
# ... execution complete at Aug 04, 2022 20:25:12 UTC in 2919.52 secs
#
# Sample Circuit:
#        ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q60_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├─────────
#        ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q60_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├──────
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q60_2: ┤ H ├──────░─┤2 Uf ├─░─┤ H ├──────░──╫──╫─┤M├───
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q60_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├
#        ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║ └╥┘
# q60_4: ┤ X ├┤ H ├─░─┤4    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫─
#        └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║
#  c2: 4/═════════════════════════════════════╩══╩══╩══╩═
#                                             0  1  2  3
#
# Constant Oracle 'Uf' =
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
#
# Balanced Oracle 'Uf' =
#  ... too large or not used!

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 20:25:17 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 13:25:18,263: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# WARNING: requested shots not equal to actual shots: 100 != 2
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 6, 0.111
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 6, 0.091, 1.0
# Average Creation Time for the 3 qubit group = 0.001 secs
# Average Elapsed Time for the 3 qubit group = 3289.935 secs
# Average Execution Time for the 3 qubit group = 3.587 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.22, 0.941, 11.377 secs
# Average Fidelity for the 3 qubit group = 1.0
# Average Hellinger Fidelity for the 3 qubit group = 1.0
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 6, 0.091
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.067, 1.0
# Average Creation Time for the 4 qubit group = 0.002 secs
# Average Elapsed Time for the 4 qubit group = 3290.743 secs
# Average Execution Time for the 4 qubit group = 3.748 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.091, 0.822, 6.121 secs
# Average Fidelity for the 4 qubit group = 0.931
# Average Hellinger Fidelity for the 4 qubit group = 0.94
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 7, 0.143
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.1, 2.0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 3293.781 secs
# Average Execution Time for the 5 qubit group = 3.91 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.958, 1.203, 10.084 secs
# Average Fidelity for the 5 qubit group = 0.787
# Average Hellinger Fidelity for the 5 qubit group = 0.8
#
# ... execution complete at Aug 04, 2022 21:20:21 UTC in 3303.825 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q157_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├─────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q157_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├──────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q157_2: ┤ H ├──────░─┤2 Uf ├─░─┤ H ├──────░──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q157_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║ └╥┘
# q157_4: ┤ X ├┤ H ├─░─┤4    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║
#   c5: 4/═════════════════════════════════════╩══╩══╩══╩═
#                                              0  1  2  3
#
# Quantum Oracle 'Uf' =
#
# q158_0: ──■───────
#           │
# q158_1: ──┼───────
#           │
# q158_2: ──┼────■──
#           │    │
# q158_3: ──┼────┼──
#         ┌─┴─┐┌─┴─┐
# q158_4: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 21:20:23 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 14:20:24,129: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# WARNING: requested shots not equal to actual shots: 100 != 3
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 9, 0.143
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 10, 0.125, 1.0
# Average Creation Time for the 3 qubit group = 0.001 secs
# Average Elapsed Time for the 3 qubit group = 3043.049 secs
# Average Execution Time for the 3 qubit group = 4.04 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.308, 1.257, 15.407 secs
# Average Fidelity for the 3 qubit group = 1.0
# Average Hellinger Fidelity for the 3 qubit group = 1.0
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 14, 0.182
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 17, 0.143, 2.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 3042.404 secs
# Average Execution Time for the 4 qubit group = 3.121 secs
# Average Transpiling, Validating, Running Times for group 4 = 2.743, 1.07, 9.397 secs
# Average Fidelity for the 4 qubit group = 0.269
# Average Hellinger Fidelity for the 4 qubit group = 0.36
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 13, 0.111
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 14, 0.1, 1.0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 3041.141 secs
# Average Execution Time for the 5 qubit group = 3.111 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.925, 1.268, 5.25 secs
# Average Fidelity for the 5 qubit group = 0.435
# Average Hellinger Fidelity for the 5 qubit group = 0.47
#
# ... execution complete at Aug 04, 2022 22:11:17 UTC in 3053.31 secs
#
# Sample Circuit:
#                    ░ ┌─┐     ┌─┐     ┌─┐     ┌───┐     ┌───┐┌─┐
# q272_0: ───────────░─┤M├─|0>─┤M├─|0>─┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─
#         ┌───┐┌───┐ ░ └╥┘     └╥┘     └╥┘     └───┘┌─┴─┐└───┘└╥┘
# q272_1: ┤ X ├┤ H ├─░──╫───────╫───────╫───────────┤ X ├──────╫──────
#         └───┘└───┘ ░  ║       ║       ║           └───┘      ║
#   c8: 4/══════════════╩═══════╩═══════╩══════════════════════╩══════
#                       0       1       2                      3

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 22:11:19 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 15:11:21,027: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ************
# Executing [1] circuits with num_qubits = 4
# WARNING: requested shots not equal to actual shots: 100 != 2
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 8, 0.2
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 15, 0.1, 2.0
# Average Creation Time for the 2 qubit group = 0.003 secs
# Average Elapsed Time for the 2 qubit group = 2967.775 secs
# Average Execution Time for the 2 qubit group = 3.537 secs
# Average Transpiling, Validating, Running Times for group 2 = 1.64, 0.991, 15.24 secs
# Average Fidelity for the 2 qubit group = 1.0
# Average Hellinger Fidelity for the 2 qubit group = 1.0
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 8, 0.167
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 15, 0.091, 4.0
# Average Creation Time for the 4 qubit group = 0.002 secs
# Average Elapsed Time for the 4 qubit group = 2973.876 secs
# Average Execution Time for the 4 qubit group = 3.855 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.045, 0.949, 12.252 secs
# Average Fidelity for the 4 qubit group = 0.563
# Average Hellinger Fidelity for the 4 qubit group = 0.59
#
# ... execution complete at Aug 04, 2022 23:01:02 UTC in 2983.229 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q355_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├─────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q355_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├──────
#         ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q355_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├───
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q355_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├
#         └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║ └╥┘
#  c10: 4/═════════════════════════════════════════════╩══╩══╩══╩═
#                                                      0  1  2  3
#
# Quantum Oracle 'Uf' =
#         ┌───┐   ┌───┐
# q356_0: ┤ X ├─■─┤ X ├
#         ├───┤ │ ├───┤
# q356_1: ┤ X ├─■─┤ X ├
#         ├───┤   ├───┤
# q356_2: ┤ X ├─■─┤ X ├
#         ├───┤ │ ├───┤
# q356_3: ┤ X ├─■─┤ X ├
#         └───┘   └───┘
#
# Quantum Oracle 'Ug' =
#
# q357_0: ─■─
#          │
# q357_1: ─■─
#
# q357_2: ─■─
#          │
# q357_3: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at Aug 04, 2022 23:01:05 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 16:01:06,216: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ... number of gates, depth = 11, 8
# ************
# Executing [1] circuits with num_qubits = 3
# ... number of gates, depth = 20, 14
# ************
# Executing [1] circuits with num_qubits = 4
# ... number of gates, depth = 29, 22
# ************
# Executing [1] circuits with num_qubits = 5
# ... number of gates, depth = 43, 32
# WARNING: requested shots not equal to actual shots: 100 != 2
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 9, 0.222
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 18, 0.211, 4.0
# Average Creation Time for the 2 qubit group = 0.002 secs
# Average Elapsed Time for the 2 qubit group = 3222.111 secs
# Average Execution Time for the 2 qubit group = 3.44 secs
# Average Transpiling, Validating, Running Times for group 2 = 1.61, 1.26, 7.958 secs
# Average Fidelity for the 2 qubit group = 1.0
# Average Hellinger Fidelity for the 2 qubit group = 1.0
#
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 15, 0.353
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 35, 0.293, 12.0
# Average Creation Time for the 3 qubit group = 0.002 secs
# Average Elapsed Time for the 3 qubit group = 3228.344 secs
# Average Execution Time for the 3 qubit group = 3.861 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.956, 0.778, 13.542 secs
# Average Fidelity for the 3 qubit group = 0.589
# Average Hellinger Fidelity for the 3 qubit group = 0.64
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 23, 0.48
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 58, 0.348, 24.0
# Average Creation Time for the 4 qubit group = 0.003 secs
# Average Elapsed Time for the 4 qubit group = 3228.485 secs
# Average Execution Time for the 4 qubit group = 4.068 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.031, 1.094, 8.086 secs
# Average Fidelity for the 4 qubit group = 0.285
# Average Hellinger Fidelity for the 4 qubit group = 0.33
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 33, 0.526
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 87, 0.37, 40.0
# Average Creation Time for the 5 qubit group = 0.004 secs
# Average Elapsed Time for the 5 qubit group = 3233.622 secs
# Average Execution Time for the 5 qubit group = 4.068 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.955, 0.942, 12.659 secs
# Average Fidelity for the 5 qubit group = 0.174
# Average Hellinger Fidelity for the 5 qubit group = 0.2
#
# ... execution complete at Aug 04, 2022 23:55:12 UTC in 3247.416 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌──────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q529_0: ┤ X ├─░─┤0     ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├────────────
#         ├───┤ ░ │      │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q529_1: ┤ X ├─░─┤1     ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├─────────
#         └───┘ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q529_2: ──────░─┤2 qft ├─░─┤ Rz(π/4) ├──░─┤2 inv_qft ├─░──╫──╫─┤M├──────
#         ┌───┐ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐
# q529_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#         └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q529_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#               ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#  c14: 5/══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                           0  1  2  3  4
#
# QFT Circuit =
#               ░                  ░                             ░            »
# q530_0: ──────░──────────────────░─────────────────────────────░────────────»
#               ░                  ░                             ░            »
# q530_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#               ░                  ░                       ┌───┐ ░      │     »
# q530_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#               ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q530_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#         ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q530_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#         └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                    ░                                   »
# «q530_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                              ┌───┐ ░      │           │          │     »
# «q530_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «             │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q530_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «        ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q530_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «        └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q530_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                    ░ └──────────┘                      »
# «                   ┌───┐ ░
# «q530_0: ─────■─────┤ H ├─░─
# «        ┌────┴────┐└───┘ ░
# «q530_1: ┤ Rz(π/2) ├──────░─
# «        └─────────┘      ░
# «q530_2: ─────────────────░─
# «                         ░
# «q530_3: ─────────────────░─
# «                         ░
# «q530_4: ─────────────────░─
# «                         ░
#
# Inverse QFT Circuit =
#         ┌───┐                                                  ░      »
# q531_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q531_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q531_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                          └──────────┘┌────┴─────┐      │       ░      »
# q531_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                      └──────────┘┌─────┴─────┐ ░      »
# q531_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                  └───────────┘ ░      »
# «                                             ░                              »
# «q531_0: ─────────────────────────────────────░──────────────────────────────»
# «                                             ░                              »
# «q531_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «        ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q531_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «        └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q531_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                    └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q531_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                └──────────┘ ░                  └──────────┘»
# «         ░                   ░       ░
# «q531_0: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q531_1: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q531_2: ─░───────────────────░───────░─
# «         ░ ┌───┐             ░       ░
# «q531_3: ─░─┤ H ├─────■───────░───────░─
# «         ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q531_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Aug 04, 2022 23:55:17 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 16:55:18,209: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ... number of gates, depth = 9, 5
# ************
# Executing [1] circuits with num_qubits = 3
# ... number of gates, depth = 15, 8
# ************
# Executing [1] circuits with num_qubits = 4
# ... number of gates, depth = 22, 12
# ************
# Executing [1] circuits with num_qubits = 5
# ... number of gates, depth = 30, 17
# WARNING: requested shots not equal to actual shots: 100 != 5
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 6, 0.143
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.286, 2.0
# Average Creation Time for the 2 qubit group = 0.005 secs
# Average Elapsed Time for the 2 qubit group = 2730.613 secs
# Average Execution Time for the 2 qubit group = 3.855 secs
# Average Transpiling, Validating, Running Times for group 2 = 1.592, 0.965, 8.11 secs
# Average Fidelity for the 2 qubit group = 0.733
# Average Hellinger Fidelity for the 2 qubit group = 0.8
#
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.333, 6.0
# Average Creation Time for the 3 qubit group = 0.002 secs
# Average Elapsed Time for the 3 qubit group = 2737.239 secs
# Average Execution Time for the 3 qubit group = 3.969 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.859, 1.173, 12.517 secs
# Average Fidelity for the 3 qubit group = 0.669
# Average Hellinger Fidelity for the 3 qubit group = 0.71
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.353, 12.0
# Average Creation Time for the 4 qubit group = 0.004 secs
# Average Elapsed Time for the 4 qubit group = 2737.486 secs
# Average Execution Time for the 4 qubit group = 3.846 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.968, 0.924, 7.139 secs
# Average Fidelity for the 4 qubit group = 0.541
# Average Hellinger Fidelity for the 4 qubit group = 0.57
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 18, 0.4
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.377, 20.0
# Average Creation Time for the 5 qubit group = 0.003 secs
# Average Elapsed Time for the 5 qubit group = 2742.487 secs
# Average Execution Time for the 5 qubit group = 4.502 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.616, 1.199, 12.277 secs
# Average Fidelity for the 5 qubit group = 0.308
# Average Hellinger Fidelity for the 5 qubit group = 0.33
#
# ... execution complete at Aug 05, 2022 00:41:13 UTC in 2755.868 secs
#
# Sample Circuit:
#         ┌───┐ ┌─────────┐  ┌──────────┐┌─┐
# q695_0: ┤ H ├─┤ Rz(11π) ├──┤0         ├┤M├────────────
#         ├───┤┌┴─────────┴┐ │          │└╥┘┌─┐
# q695_1: ┤ H ├┤ Rz(11π/2) ├─┤1         ├─╫─┤M├─────────
#         ├───┤├───────────┤ │          │ ║ └╥┘┌─┐
# q695_2: ┤ H ├┤ Rz(11π/4) ├─┤2 inv_qft ├─╫──╫─┤M├──────
#         ├───┤├───────────┤ │          │ ║  ║ └╥┘┌─┐
# q695_3: ┤ H ├┤ Rz(11π/8) ├─┤3         ├─╫──╫──╫─┤M├───
#         ├───┤├───────────┴┐│          │ ║  ║  ║ └╥┘┌─┐
# q695_4: ┤ H ├┤ Rz(11π/16) ├┤4         ├─╫──╫──╫──╫─┤M├
#         └───┘└────────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#  c18: 5/════════════════════════════════╩══╩══╩══╩══╩═
#                                         0  1  2  3  4
#
# Inverse QFT Circuit =
#         ┌───┐                                                  ░      »
# q696_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q696_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q696_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                          └──────────┘┌────┴─────┐      │       ░      »
# q696_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                      └──────────┘┌─────┴─────┐ ░      »
# q696_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                  └───────────┘ ░      »
# «                                             ░                              »
# «q696_0: ─────────────────────────────────────░──────────────────────────────»
# «                                             ░                              »
# «q696_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «        ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q696_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «        └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q696_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                    └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q696_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                └──────────┘ ░                  └──────────┘»
# «         ░                   ░       ░
# «q696_0: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q696_1: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q696_2: ─░───────────────────░───────░─
# «         ░ ┌───┐             ░       ░
# «q696_3: ─░─┤ H ├─────■───────░───────░─
# «         ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q696_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# ... execution starting at Aug 05, 2022 00:41:16 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 17:41:16,805: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# WARNING: requested shots not equal to actual shots: 100 != 2
# ************
# Average Depth, ξ (xi) for the 2 qubit group = 12, 0.111
# Average Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 14, 0.111, 2.0
# Average Creation Time for the 2 qubit group = 0.002 secs
# Average Elapsed Time for the 2 qubit group = 3024.042 secs
# Average Execution Time for the 2 qubit group = 3.722 secs
# Average Transpiling, Validating, Running Times for group 2 = 1.485, 1.028, 19.529 secs
# Average Fidelity for the 2 qubit group = 1.0
# Average Hellinger Fidelity for the 2 qubit group = 1.0
#
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 22, 0.085
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 51, 0.308, 24.0
# Average Creation Time for the 3 qubit group = 0.004 secs
# Average Elapsed Time for the 3 qubit group = 3048.307 secs
# Average Execution Time for the 3 qubit group = 3.824 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.41, 1.103, 30.715 secs
# Average Fidelity for the 3 qubit group = 0.517
# Average Hellinger Fidelity for the 3 qubit group = 0.67
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 38, 0.073
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 168, 0.396, 84.0
# Average Creation Time for the 4 qubit group = 0.006 secs
# Average Elapsed Time for the 4 qubit group = 3065.803 secs
# Average Execution Time for the 4 qubit group = 3.964 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.885, 0.841, 28.208 secs
# Average Fidelity for the 4 qubit group = 0.0
# Average Hellinger Fidelity for the 4 qubit group = 0.183
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 42, 0.068
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 607, 0.384, 288.0
# Average Creation Time for the 5 qubit group = 0.008 secs
# Average Elapsed Time for the 5 qubit group = 3083.662 secs
# Average Execution Time for the 5 qubit group = 4.573 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.232, 1.034, 25.966 secs
# Average Fidelity for the 5 qubit group = 0.045
# Average Hellinger Fidelity for the 5 qubit group = 0.085
#
# ... execution complete at Aug 05, 2022 01:32:54 UTC in 3097.892 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q881_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#         ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q881_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#         ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q881_2: ┤ H ├─░─┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░─»
#         ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q881_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#         ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q881_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#         └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#  c22: 5/══════════════════════════════════════════════════════════════»
#                                                                       »
# «        ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─┐
# «q881_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤M├────────────
# «        │         ││           │ ░ │         ││           │ ░ └╥┘┌─┐
# «q881_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░──╫─┤M├─────────
# «        │         ││           │ ░ │         ││           │ ░  ║ └╥┘┌─┐
# «q881_2: ┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░──╫──╫─┤M├──────
# «        │         ││           │ ░ │         ││           │ ░  ║  ║ └╥┘┌─┐
# «q881_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░──╫──╫──╫─┤M├───
# «        │         ││           │ ░ │         ││           │ ░  ║  ║  ║ └╥┘┌─┐
# «q881_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░──╫──╫──╫──╫─┤M├
# «        └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ └╥┘
# « c22: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                               0  1  2  3  4
#
# Oracle =
#                         ░
# q888_0: ───────■────────░──────
#                │        ░
# q888_1: ───────■────────░──────
#                │        ░
# q888_2: ───────■────────░──────
#         ┌───┐  │        ░ ┌───┐
# q888_3: ┤ X ├──■────────░─┤ X ├
#         ├───┤┌─┴─┐┌───┐ ░ └───┘
# q888_4: ┤ H ├┤ X ├┤ H ├─░──────
#         └───┘└───┘└───┘ ░
#
# Diffuser =
#         ┌───┐┌───┐                ░ ┌───┐┌───┐
# q889_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#         ├───┤├───┤       │        ░ ├───┤├───┤
# q889_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#         ├───┤├───┤       │        ░ ├───┤├───┤
# q889_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#         ├───┤├───┤       │        ░ ├───┤├───┤
# q889_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#         ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q889_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#         └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 05, 2022 01:32:56 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 18:32:56,516: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# WARNING: requested shots not equal to actual shots: 100 != 1
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 16, 0.316
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 19, 0.261, 6.0
# Average Creation Time for the 3 qubit group = 0.009 secs
# Average Elapsed Time for the 3 qubit group = 2813.315 secs
# Average Execution Time for the 3 qubit group = 3.714 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.823, 1.106, 15.189 secs
# Average Fidelity for the 3 qubit group = 1.0
# Average Hellinger Fidelity for the 3 qubit group = 1.0
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.286, 10.0
# Average Creation Time for the 4 qubit group = 0.008 secs
# Average Elapsed Time for the 4 qubit group = 2812.859 secs
# Average Execution Time for the 4 qubit group = 4.28 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.09, 1.214, 9.135 secs
# Average Fidelity for the 4 qubit group = 0.474
# Average Hellinger Fidelity for the 4 qubit group = 0.54
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 42, 0.321, 18.0
# Average Creation Time for the 5 qubit group = 0.01 secs
# Average Elapsed Time for the 5 qubit group = 2817.861 secs
# Average Execution Time for the 5 qubit group = 4.245 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.701, 1.399, 13.917 secs
# Average Fidelity for the 5 qubit group = 0.36
# Average Hellinger Fidelity for the 5 qubit group = 0.4
#
# ... execution complete at Aug 05, 2022 02:20:04 UTC in 2828.305 secs
#
# Sample Circuit:
#          ┌───┐ ░                              ░ ┌──────────┐ ░ ┌─┐
# q1054_0: ┤ H ├─░─────────────────────────■────░─┤0         ├─░─┤M├─────────
#          ├───┤ ░                         │    ░ │          │ ░ └╥┘┌─┐
# q1054_1: ┤ H ├─░──────────────────■──────┼────░─┤1         ├─░──╫─┤M├──────
#          ├───┤ ░                  │      │    ░ │  inv_qft │ ░  ║ └╥┘┌─┐
# q1054_2: ┤ H ├─░───────────■──────┼──────┼────░─┤2         ├─░──╫──╫─┤M├───
#          ├───┤ ░           │      │      │    ░ │          │ ░  ║  ║ └╥┘┌─┐
# q1054_3: ┤ H ├─░────■──────┼──────┼──────┼────░─┤3         ├─░──╫──╫──╫─┤M├
#          ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░ └──────────┘ ░  ║  ║  ║ └╥┘
# q1054_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░──────────────░──╫──╫──╫──╫─
#          └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░              ░  ║  ║  ║  ║
#   c25: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                 0  1  2  3
#
# Phase Operator 'U' =
#    ┌─────────┐
# q: ┤ P(3π/2) ├
#    └─────────┘
#
# Inverse QFT Circuit =
#          ┌───┐                                     ░                  »
# q1056_0: ┤ H ├─────■───────────■───────────■───────░──────────────────»
#          └───┘┌────┴─────┐     │           │       ░ ┌───┐            »
# q1056_1: ─────┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■──────»
#               └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐»
# q1056_2: ─────────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├»
#                           └──────────┘┌────┴─────┐ ░      └──────────┘»
# q1056_3: ─────────────────────────────┤ Rz(-π/8) ├─░──────────────────»
#                                       └──────────┘ ░                  »
# «                      ░                   ░       ░
# «q1056_0: ─────────────░───────────────────░───────░─
# «                      ░                   ░       ░
# «q1056_1: ─────■───────░───────────────────░───────░─
# «              │       ░ ┌───┐             ░       ░
# «q1056_2: ─────┼───────░─┤ H ├─────■───────░───────░─
# «         ┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1056_3: ┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 05, 2022 04:04:02 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 21:04:03,210: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 61, 0.385, 30.0
# Average Creation Time for the 3 qubit group = 0.019 secs
# Average Elapsed Time for the 3 qubit group = 3457.734 secs
# Average Execution Time for the 3 qubit group = 3.885 secs
# Average Transpiling, Validating, Running Times for group 3 = 4.573, 1.351, 48.266 secs
# Average Fidelity for the 3 qubit group = 0.44
# Average Hellinger Fidelity for the 3 qubit group = 0.72
#
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 175, 0.398, 88.0
# Average Creation Time for the 4 qubit group = 0.021 secs
# Average Elapsed Time for the 4 qubit group = 3460.469 secs
# Average Execution Time for the 4 qubit group = 4.123 secs
# Average Transpiling, Validating, Running Times for group 4 = 2.857, 1.401, 14.48 secs
# Average Fidelity for the 4 qubit group = 0.053
# Average Hellinger Fidelity for the 4 qubit group = 0.29
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 363, 0.404, 188.0
# Average Creation Time for the 5 qubit group = 0.029 secs
# Average Elapsed Time for the 5 qubit group = 3458.574 secs
# Average Execution Time for the 5 qubit group = 4.211 secs
# Average Transpiling, Validating, Running Times for group 5 = 4.039, 1.3, 8.295 secs
# Average Fidelity for the 5 qubit group = 0.182
# Average Hellinger Fidelity for the 5 qubit group = 0.387
#
# ... execution complete at Aug 05, 2022 05:01:57 UTC in 3474.671 secs
#
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q2032_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q2032_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q2032_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q2031_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q2031_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c34: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q2032_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q2032_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q2032_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q2031_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q2031_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c34: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q2033: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                           ┌───┐
# q_0: ─────────────────────┤ X ├
#      ┌─────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(π/2) ├┤ X ├┤ X ├──■──
#      └─────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q2034_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q2034_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q2034_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Aug 05, 2022 05:02:04 UTC
# ibmqfactory.load_account:WARNING:2022-08-04 22:02:05,559: Credentials are already in use. The existing account in the session will be replaced.
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 64
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
