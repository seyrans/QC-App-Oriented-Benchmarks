# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
min_qubits=2
max_qubits=5
max_circuits=1
num_shots=100

backend_id="ibmq_manila"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = None

# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"
# group="YOUR_GROUP_NAME"
# project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify the backend using a known "backend_id"
# # Use 'sabre' layout for IBM backends
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre' }
# backend_id="ibmq_belem"

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # *** Use these lines when running on hardware backend, to limit use of resources
# min_qubits=2
# max_qubits=5
# max_circuits=1
# num_shots=100

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Add Qiskit pass manager as a custom 'transformer' method
import _common.transformers.qiskit_passmgr as qiskit_passmgr
exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre', "transformer": qiskit_passmgr.do_transform }

# # Example of TrueQ Randomized Compilation
# import _common.transformers.trueq_rc as trueq_rc
# exec_options = { "optimization_level":3, "layout_method":'sabre', "routing_method":'sabre', "transformer": trueq_rc.local_rc } 

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options = { "noise_model": custom_qiskit_noise_model.my_noise_model() }

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:08:34 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 3 0
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 6, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0, 0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 0.119 secs
# Average Execution Time for the 4 qubit group = 0.003 secs
# Average Fidelity for the 4 qubit group = 0.989
# Average Hellinger Fidelity for the 4 qubit group = 0.99
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 6, 0
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 6, 0, 0
# Average Creation Time for the 5 qubit group = 0.001 secs
# Average Elapsed Time for the 5 qubit group = 0.328 secs
# Average Execution Time for the 5 qubit group = 0.007 secs
# Average Fidelity for the 5 qubit group = 0.979
# Average Hellinger Fidelity for the 5 qubit group = 0.98
#
# ... execution complete at Aug 04, 2022 16:08:35 UTC in 0.747 secs
#
# Sample Circuit:
#        ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q59_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├─────────
#        ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q59_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├──────
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q59_2: ┤ H ├──────░─┤2 Uf ├─░─┤ H ├──────░──╫──╫─┤M├───
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q59_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├
#        ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║ └╥┘
# q59_4: ┤ X ├┤ H ├─░─┤4    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫─
#        └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║
#  c2: 4/═════════════════════════════════════╩══╩══╩══╩═
#                                             0  1  2  3
#
# Constant Oracle 'Uf' =
#
# q_0: ─────
#
# q_1: ─────
#
# q_2: ─────
#
# q_3: ─────
#      ┌───┐
# q_4: ┤ X ├
#      └───┘
#
# Balanced Oracle 'Uf' =
#  ... too large or not used!

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:08:37 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 3 2
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 6, 0.091
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.067, 1.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 0.149 secs
# Average Execution Time for the 4 qubit group = 0.005 secs
# Average Fidelity for the 4 qubit group = 0.92
# Average Hellinger Fidelity for the 4 qubit group = 0.93
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 7, 0.143
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.1, 2.0
# Average Creation Time for the 5 qubit group = 0.002 secs
# Average Elapsed Time for the 5 qubit group = 0.083 secs
# Average Execution Time for the 5 qubit group = 0.003 secs
# Average Fidelity for the 5 qubit group = 0.925
# Average Hellinger Fidelity for the 5 qubit group = 0.93
#
# ... execution complete at Aug 04, 2022 16:08:37 UTC in 0.229 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q165_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├─────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q165_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├──────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q165_2: ┤ H ├──────░─┤2 Uf ├─░─┤ H ├──────░──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q165_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║ └╥┘
# q165_4: ┤ X ├┤ H ├─░─┤4    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║
#   c5: 4/═════════════════════════════════════╩══╩══╩══╩═
#                                              0  1  2  3
#
# Quantum Oracle 'Uf' =
#
# q166_0: ──■───────
#           │
# q166_1: ──┼───────
#           │
# q166_2: ──┼────■──
#           │    │
# q166_3: ──┼────┼──
#         ┌─┴─┐┌─┴─┐
# q166_4: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:08:40 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 3 2
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 14, 0.182
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 17, 0.143, 2.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 0.352 secs
# Average Execution Time for the 4 qubit group = 0.019 secs
# Average Fidelity for the 4 qubit group = 0.851
# Average Hellinger Fidelity for the 4 qubit group = 0.87
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 13, 0.111
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 14, 0.1, 1.0
# Average Creation Time for the 5 qubit group = 0.005 secs
# Average Elapsed Time for the 5 qubit group = 0.214 secs
# Average Execution Time for the 5 qubit group = 0.018 secs
# Average Fidelity for the 5 qubit group = 0.957
# Average Hellinger Fidelity for the 5 qubit group = 0.96
#
# ... execution complete at Aug 04, 2022 16:08:40 UTC in 0.45 secs
#
# Sample Circuit:
#                    ░ ┌─┐     ┌─┐     ┌─┐     ┌───┐     ┌───┐┌─┐
# q292_0: ───────────░─┤M├─|0>─┤M├─|0>─┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─
#         ┌───┐┌───┐ ░ └╥┘     └╥┘     └╥┘     └───┘┌─┴─┐└───┘└╥┘
# q292_1: ┤ X ├┤ H ├─░──╫───────╫───────╫───────────┤ X ├──────╫──────
#         └───┘└───┘ ░  ║       ║       ║           └───┘      ║
#   c8: 4/══════════════╩═══════╩═══════╩══════════════════════╩══════
#                       0       1       2                      3

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:08:43 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 2 2
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 8, 0.2
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 15, 0.1, 4.0
# Average Creation Time for the 4 qubit group = 0.004 secs
# Average Elapsed Time for the 4 qubit group = 0.398 secs
# Average Execution Time for the 4 qubit group = 0.004 secs
# Average Fidelity for the 4 qubit group = 0.904
# Average Hellinger Fidelity for the 4 qubit group = 0.91
#
# ... execution complete at Aug 04, 2022 16:08:44 UTC in 0.487 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q368_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├─────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q368_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├──────
#         ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q368_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├───
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q368_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├
#         └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║ └╥┘
#  c10: 4/═════════════════════════════════════════════╩══╩══╩══╩═
#                                                      0  1  2  3
#
# Quantum Oracle 'Uf' =
#
# q369_0: ──────■──────
#         ┌───┐ │ ┌───┐
# q369_1: ┤ X ├─■─┤ X ├
#         └───┘   └───┘
# q369_2: ──────■──────
#         ┌───┐ │ ┌───┐
# q369_3: ┤ X ├─■─┤ X ├
#         └───┘   └───┘
#
# Quantum Oracle 'Ug' =
#
# q370_0: ─■─
#          │
# q370_1: ─■─
#
# q370_2: ─■─
#          │
# q370_3: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at Aug 04, 2022 16:08:46 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 2 2
# ... exception = 'NoneType' object has no attribute '_gates'
# ... number of gates, depth = 11, 8
# ************
# Executing [1] circuits with num_qubits = 3
# ... number of gates, depth = 20, 14
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 15, 0.353
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 35, 0.293, 12.0
# Average Creation Time for the 3 qubit group = 0.002 secs
# Average Elapsed Time for the 3 qubit group = 1.061 secs
# Average Execution Time for the 3 qubit group = 0.007 secs
# Average Fidelity for the 3 qubit group = 0.726
# Average Hellinger Fidelity for the 3 qubit group = 0.76
#
# ************
# Executing [1] circuits with num_qubits = 4
# ... number of gates, depth = 29, 22
# ************
# Executing [1] circuits with num_qubits = 5
# ... number of gates, depth = 43, 32
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 23, 0.48
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 58, 0.348, 24.0
# Average Creation Time for the 4 qubit group = 0.003 secs
# Average Elapsed Time for the 4 qubit group = 1.187 secs
# Average Execution Time for the 4 qubit group = 0.007 secs
# Average Fidelity for the 4 qubit group = 0.616
# Average Hellinger Fidelity for the 4 qubit group = 0.64
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 33, 0.526
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 87, 0.37, 40.0
# Average Creation Time for the 5 qubit group = 0.004 secs
# Average Elapsed Time for the 5 qubit group = 0.75 secs
# Average Execution Time for the 5 qubit group = 0.014 secs
# Average Fidelity for the 5 qubit group = 0.381
# Average Hellinger Fidelity for the 5 qubit group = 0.4
#
# ... execution complete at Aug 04, 2022 16:08:48 UTC in 2.346 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌──────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q601_0: ┤ X ├─░─┤0     ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├────────────
#         ├───┤ ░ │      │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q601_1: ┤ X ├─░─┤1     ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├─────────
#         └───┘ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q601_2: ──────░─┤2 qft ├─░─┤ Rz(π/4) ├──░─┤2 inv_qft ├─░──╫──╫─┤M├──────
#         ┌───┐ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐
# q601_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#         └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q601_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#               ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#  c14: 5/══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                           0  1  2  3  4
#
# QFT Circuit =
#               ░                  ░                             ░            »
# q602_0: ──────░──────────────────░─────────────────────────────░────────────»
#               ░                  ░                             ░            »
# q602_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#               ░                  ░                       ┌───┐ ░      │     »
# q602_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#               ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q602_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#         ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q602_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#         └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                    ░                                   »
# «q602_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                              ┌───┐ ░      │           │          │     »
# «q602_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «             │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q602_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «        ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q602_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «        └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q602_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                    ░ └──────────┘                      »
# «                   ┌───┐ ░
# «q602_0: ─────■─────┤ H ├─░─
# «        ┌────┴────┐└───┘ ░
# «q602_1: ┤ Rz(π/2) ├──────░─
# «        └─────────┘      ░
# «q602_2: ─────────────────░─
# «                         ░
# «q602_3: ─────────────────░─
# «                         ░
# «q602_4: ─────────────────░─
# «                         ░
#
# Inverse QFT Circuit =
#         ┌───┐                                                  ░      »
# q603_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q603_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q603_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                          └──────────┘┌────┴─────┐      │       ░      »
# q603_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                      └──────────┘┌─────┴─────┐ ░      »
# q603_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                  └───────────┘ ░      »
# «                                             ░                              »
# «q603_0: ─────────────────────────────────────░──────────────────────────────»
# «                                             ░                              »
# «q603_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «        ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q603_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «        └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q603_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                    └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q603_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                └──────────┘ ░                  └──────────┘»
# «         ░                   ░       ░
# «q603_0: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q603_1: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q603_2: ─░───────────────────░───────░─
# «         ░ ┌───┐             ░       ░
# «q603_3: ─░─┤ H ├─────■───────░───────░─
# «         ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q603_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Aug 04, 2022 16:08:51 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 2 2
# ... exception = 'NoneType' object has no attribute '_gates'
# ... number of gates, depth = 9, 5
# ************
# Executing [1] circuits with num_qubits = 3
# ... number of gates, depth = 15, 8
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.333, 6.0
# Average Creation Time for the 3 qubit group = 0.001 secs
# Average Elapsed Time for the 3 qubit group = 0.14 secs
# Average Execution Time for the 3 qubit group = 0.007 secs
# Average Fidelity for the 3 qubit group = 0.794
# Average Hellinger Fidelity for the 3 qubit group = 0.82
#
# ************
# Executing [1] circuits with num_qubits = 4
# ... number of gates, depth = 22, 12
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.353, 12.0
# Average Creation Time for the 4 qubit group = 0.001 secs
# Average Elapsed Time for the 4 qubit group = 0.199 secs
# Average Execution Time for the 4 qubit group = 0.005 secs
# Average Fidelity for the 4 qubit group = 0.744
# Average Hellinger Fidelity for the 4 qubit group = 0.76
#
# ************
# Executing [1] circuits with num_qubits = 5
# ... number of gates, depth = 30, 17
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 18, 0.4
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.377, 20.0
# Average Creation Time for the 5 qubit group = 0.002 secs
# Average Elapsed Time for the 5 qubit group = 0.235 secs
# Average Execution Time for the 5 qubit group = 0.004 secs
# Average Fidelity for the 5 qubit group = 0.587
# Average Hellinger Fidelity for the 5 qubit group = 0.6
#
# ... execution complete at Aug 04, 2022 16:08:52 UTC in 0.736 secs
#
# Sample Circuit:
#         ┌───┐ ┌─────────┐  ┌──────────┐┌─┐
# q859_0: ┤ H ├─┤ Rz(11π) ├──┤0         ├┤M├────────────
#         ├───┤┌┴─────────┴┐ │          │└╥┘┌─┐
# q859_1: ┤ H ├┤ Rz(11π/2) ├─┤1         ├─╫─┤M├─────────
#         ├───┤├───────────┤ │          │ ║ └╥┘┌─┐
# q859_2: ┤ H ├┤ Rz(11π/4) ├─┤2 inv_qft ├─╫──╫─┤M├──────
#         ├───┤├───────────┤ │          │ ║  ║ └╥┘┌─┐
# q859_3: ┤ H ├┤ Rz(11π/8) ├─┤3         ├─╫──╫──╫─┤M├───
#         ├───┤├───────────┴┐│          │ ║  ║  ║ └╥┘┌─┐
# q859_4: ┤ H ├┤ Rz(11π/16) ├┤4         ├─╫──╫──╫──╫─┤M├
#         └───┘└────────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#  c18: 5/════════════════════════════════╩══╩══╩══╩══╩═
#                                         0  1  2  3  4
#
# Inverse QFT Circuit =
#         ┌───┐                                                  ░      »
# q860_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#         └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q860_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#              └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q860_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                          └──────────┘┌────┴─────┐      │       ░      »
# q860_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                      └──────────┘┌─────┴─────┐ ░      »
# q860_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                  └───────────┘ ░      »
# «                                             ░                              »
# «q860_0: ─────────────────────────────────────░──────────────────────────────»
# «                                             ░                              »
# «q860_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «        ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q860_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «        └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q860_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                    └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q860_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                └──────────┘ ░                  └──────────┘»
# «         ░                   ░       ░
# «q860_0: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q860_1: ─░───────────────────░───────░─
# «         ░                   ░       ░
# «q860_2: ─░───────────────────░───────░─
# «         ░ ┌───┐             ░       ░
# «q860_3: ─░─┤ H ├─────■───────░───────░─
# «         ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q860_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:08:55 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 2 2
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 26, 0.085
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 51, 0.308, 24.0
# Average Creation Time for the 3 qubit group = 0.003 secs
# Average Elapsed Time for the 3 qubit group = 1.112 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.583
# Average Hellinger Fidelity for the 3 qubit group = 0.715
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 38, 0.073
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 168, 0.396, 84.0
# Average Creation Time for the 4 qubit group = 0.005 secs
# Average Elapsed Time for the 4 qubit group = 3.484 secs
# Average Execution Time for the 4 qubit group = 0.007 secs
# Average Fidelity for the 4 qubit group = 0.269
# Average Hellinger Fidelity for the 4 qubit group = 0.407
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 42, 0.068
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 607, 0.384, 288.0
# Average Creation Time for the 5 qubit group = 0.007 secs
# Average Elapsed Time for the 5 qubit group = 2.676 secs
# Average Execution Time for the 5 qubit group = 0.021 secs
# Average Fidelity for the 5 qubit group = 0.0
# Average Hellinger Fidelity for the 5 qubit group = 0.028
#
# ... execution complete at Aug 04, 2022 16:08:59 UTC in 3.913 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q1368_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1368_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1368_2: ┤ H ├─░─┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1368_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q1368_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#          └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#   c22: 5/══════════════════════════════════════════════════════════════»
#                                                                        »
# «         ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─┐
# «q1368_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤M├────────────
# «         │         ││           │ ░ │         ││           │ ░ └╥┘┌─┐
# «q1368_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░──╫─┤M├─────────
# «         │         ││           │ ░ │         ││           │ ░  ║ └╥┘┌─┐
# «q1368_2: ┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░──╫──╫─┤M├──────
# «         │         ││           │ ░ │         ││           │ ░  ║  ║ └╥┘┌─┐
# «q1368_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░──╫──╫──╫─┤M├───
# «         │         ││           │ ░ │         ││           │ ░  ║  ║  ║ └╥┘┌─┐
# «q1368_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░──╫──╫──╫──╫─┤M├
# «         └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ └╥┘
# «  c22: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                                0  1  2  3  4
#
# Oracle =
#                          ░
# q1375_0: ───────■────────░──────
#                 │        ░
# q1375_1: ───────■────────░──────
#                 │        ░
# q1375_2: ───────■────────░──────
#          ┌───┐  │        ░ ┌───┐
# q1375_3: ┤ X ├──■────────░─┤ X ├
#          ├───┤┌─┴─┐┌───┐ ░ └───┘
# q1375_4: ┤ H ├┤ X ├┤ H ├─░──────
#          └───┘└───┘└───┘ ░
#
# Diffuser =
#          ┌───┐┌───┐                ░ ┌───┐┌───┐
# q1376_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1376_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1376_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q1376_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q1376_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#          └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:09:01 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 3 0.5
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.286, 10.0
# Average Creation Time for the 4 qubit group = 0.006 secs
# Average Elapsed Time for the 4 qubit group = 0.557 secs
# Average Execution Time for the 4 qubit group = 0.004 secs
# Average Fidelity for the 4 qubit group = 0.794
# Average Hellinger Fidelity for the 4 qubit group = 0.82
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 42, 0.321, 18.0
# Average Creation Time for the 5 qubit group = 0.009 secs
# Average Elapsed Time for the 5 qubit group = 0.305 secs
# Average Execution Time for the 5 qubit group = 0.005 secs
# Average Fidelity for the 5 qubit group = 0.691
# Average Hellinger Fidelity for the 5 qubit group = 0.71
#
# ... execution complete at Aug 04, 2022 16:09:02 UTC in 0.685 secs
#
# Sample Circuit:
#          ┌───┐ ░                              ░ ┌──────────┐ ░ ┌─┐
# q2187_0: ┤ H ├─░─────────────────────────■────░─┤0         ├─░─┤M├─────────
#          ├───┤ ░                         │    ░ │          │ ░ └╥┘┌─┐
# q2187_1: ┤ H ├─░──────────────────■──────┼────░─┤1         ├─░──╫─┤M├──────
#          ├───┤ ░                  │      │    ░ │  inv_qft │ ░  ║ └╥┘┌─┐
# q2187_2: ┤ H ├─░───────────■──────┼──────┼────░─┤2         ├─░──╫──╫─┤M├───
#          ├───┤ ░           │      │      │    ░ │          │ ░  ║  ║ └╥┘┌─┐
# q2187_3: ┤ H ├─░────■──────┼──────┼──────┼────░─┤3         ├─░──╫──╫──╫─┤M├
#          ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░ └──────────┘ ░  ║  ║  ║ └╥┘
# q2187_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░──────────────░──╫──╫──╫──╫─
#          └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░              ░  ║  ║  ║  ║
#   c25: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                 0  1  2  3
#
# Phase Operator 'U' =
#    ┌─────────┐
# q: ┤ P(3π/2) ├
#    └─────────┘
#
# Inverse QFT Circuit =
#          ┌───┐                                     ░                  »
# q2189_0: ┤ H ├─────■───────────■───────────■───────░──────────────────»
#          └───┘┌────┴─────┐     │           │       ░ ┌───┐            »
# q2189_1: ─────┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■──────»
#               └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐»
# q2189_2: ─────────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├»
#                           └──────────┘┌────┴─────┐ ░      └──────────┘»
# q2189_3: ─────────────────────────────┤ Rz(-π/8) ├─░──────────────────»
#                                       └──────────┘ ░                  »
# «                      ░                   ░       ░
# «q2189_0: ─────────────░───────────────────░───────░─
# «                      ░                   ░       ░
# «q2189_1: ─────■───────░───────────────────░───────░─
# «              │       ░ ┌───┐             ░       ░
# «q2189_2: ─────┼───────░─┤ H ├─────■───────░───────░─
# «         ┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q2189_3: ┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:09:04 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 3
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 3 1
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 175, 0.398, 88.0
# Average Creation Time for the 4 qubit group = 0.02 secs
# Average Elapsed Time for the 4 qubit group = 3.001 secs
# Average Execution Time for the 4 qubit group = 0.012 secs
# Average Fidelity for the 4 qubit group = 0.227
# Average Hellinger Fidelity for the 4 qubit group = 0.42
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 363, 0.404, 188.0
# Average Creation Time for the 5 qubit group = 0.029 secs
# Average Elapsed Time for the 5 qubit group = 2.148 secs
# Average Execution Time for the 5 qubit group = 0.014 secs
# Average Fidelity for the 5 qubit group = 0.0
# Average Hellinger Fidelity for the 5 qubit group = 0.236
#
# ... execution complete at Aug 04, 2022 16:09:08 UTC in 3.632 secs
#
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q2612_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q2612_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q2612_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q2611_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q2611_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c28: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q2612_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q2612_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q2612_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q2611_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q2611_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «  c28: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q2613: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                           ┌───┐
# q_0: ─────────────────────┤ X ├
#      ┌─────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(π/2) ├┤ X ├┤ X ├──■──
#      └─────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q2614_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q2614_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q2614_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling Benchmark Program - Qiskit
# ... using circuit method 2
# ... execution starting at Aug 04, 2022 16:09:10 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 4
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 4 0.75
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation Time for the 5 qubit group = 0.034 secs
# Average Elapsed Time for the 5 qubit group = 2.47 secs
# Average Execution Time for the 5 qubit group = 0.017 secs
# Average Fidelity for the 5 qubit group = 0.021
# Average Hellinger Fidelity for the 5 qubit group = 0.265
#
# ... execution complete at Aug 04, 2022 16:09:14 UTC in 3.552 secs
#
# Sample Circuit:
#          ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q3188_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q3188_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#          ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q3189_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q3189_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#          ├───┤ │      │└──────┘└──────┘                                 ░ »
# q3189_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#          └───┘ └──────┘                                                 ░ »
#   c30: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «                      ░
# «q3188_0: ─────────────░──────────
# «                      ░
# «q3188_1: ─────────────░──────────
# «         ┌──────────┐ ░ ┌─┐
# «q3189_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q3189_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q3189_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «  c30: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q3190: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#          ┌────┐┌────┐
# q3185_0: ┤0   ├┤0   ├
#          │  R ││  F │
# q3185_1: ┤1   ├┤1   ├
#          └────┘└────┘
#
# Distribution Generator 'R' =
#          ┌───┐
# q3186_0: ┤ H ├
#          └───┘
# q3186_1: ─────
#
#
# Function Generator 'F' =
#
# q3187_0: ──■──
#          ┌─┴─┐
# q3187_1: ┤ X ├
#          └───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q3191_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q3191_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q3191_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian-Simulation Benchmark Program - Qiskit
# ... execution starting at Aug 04, 2022 16:09:16 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 2
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 2 0
# ... exception = 'NoneType' object has no attribute '_gates'
# ************
# Executing [1] circuits with num_qubits = 3
# ************
# Executing [1] circuits with num_qubits = 4
# ************
# Average Depth, ξ (xi) for the 3 qubit group = 44, 0.265
# Average Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 44, 0.265, 18.0
# Average Creation Time for the 3 qubit group = 0.004 secs
# Average Elapsed Time for the 3 qubit group = 0.497 secs
# Average Execution Time for the 3 qubit group = 0.004 secs
# Average Fidelity for the 3 qubit group = 0.617
# Average Hellinger Fidelity for the 3 qubit group = 0.671
#
# ************
# Executing [1] circuits with num_qubits = 5
# ************
# Average Depth, ξ (xi) for the 4 qubit group = 50, 0.276
# Average Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 44, 0.293, 27.0
# Average Creation Time for the 4 qubit group = 0.005 secs
# Average Elapsed Time for the 4 qubit group = 0.656 secs
# Average Execution Time for the 4 qubit group = 0.005 secs
# Average Fidelity for the 4 qubit group = 0.596
# Average Hellinger Fidelity for the 4 qubit group = 0.628
#
# ************
# Average Depth, ξ (xi) for the 5 qubit group = 50, 0.279
# Average Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 44, 0.293, 36.0
# Average Creation Time for the 5 qubit group = 0.008 secs
# Average Elapsed Time for the 5 qubit group = 0.342 secs
# Average Execution Time for the 5 qubit group = 0.006 secs
# Average Fidelity for the 5 qubit group = 0.433
# Average Hellinger Fidelity for the 5 qubit group = 0.46
#
# ... execution complete at Aug 04, 2022 16:09:17 UTC in 1.136 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# q3874_0: ┤ X ├─░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
#          └───┘ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q3874_1: ──────░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
#          ┌───┐ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# q3874_2: ┤ X ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# q3874_3: ──────░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
#          ┌───┐ ░  ├──────────────┤ ├──────────────┤ ░ └─────────────┘»
# q3874_4: ┤ X ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░────────────────»
#          └───┘ ░  └──────────────┘ └──────────────┘ ░                »
#   c34: 5/════════════════════════════════════════════════════════════»
#                                                                      »
# «                         ░ ┌───────────────┐ ┌──────────────┐ ░ »
# «q3874_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─»
# «         ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ »
# «q3874_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─»
# «         │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ »
# «q3874_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─»
# «         ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q3874_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─»
# «         │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q3874_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─»
# «         └─────────────┘ ░  └──────────────┘ └──────────────┘ ░ »
# «  c34: 5/═══════════════════════════════════════════════════════»
# «                                                                »
# «         ┌─────────────┐                ░ ┌───────────────┐ ┌──────────────┐»
# «q3874_0: ┤0            ├────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├»
# «         │  xxyyzz_opt │┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤»
# «q3874_1: ┤1            ├┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤»
# «q3874_2: ┤0            ├┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├»
# «         │  xxyyzz_opt │├─────────────┤ ░  ├──────────────┤ ├──────────────┤»
# «q3874_3: ┤1            ├┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├»
# «         └─────────────┘│  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤»
# «q3874_4: ───────────────┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├»
# «                        └─────────────┘ ░  └──────────────┘ └──────────────┘»
# «  c34: 5/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «          ░ ┌─────────────┐                ░ ┌─┐
# «q3874_0: ─░─┤0            ├────────────────░─┤M├────────────
# «          ░ │  xxyyzz_opt │┌─────────────┐ ░ └╥┘┌─┐
# «q3874_1: ─░─┤1            ├┤0            ├─░──╫─┤M├─────────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q3874_2: ─░─┤0            ├┤1            ├─░──╫──╫─┤M├──────
# «          ░ │  xxyyzz_opt │├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q3874_3: ─░─┤1            ├┤0            ├─░──╫──╫──╫─┤M├───
# «          ░ └─────────────┘│  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q3874_4: ─░────────────────┤1            ├─░──╫──╫──╫──╫─┤M├
# «          ░                └─────────────┘ ░  ║  ║  ║  ║ └╥┘
# «  c34: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
# «                                              0  1  2  3  4
#
# XXYYZZ_opt =
#                        ┌───┐┌─────────────┐                    ┌───┐»
# q3886_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#          ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q3886_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#          └────────────┘      └────────────┘└───┘└─────────────┘     »
# «         ┌─────────────┐
# «q3886_0: ┤ Rz(-1.5708) ├
# «         └─────────────┘
# «q3886_1: ───────────────
# «

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Variational Quantum Eigensolver Benchmark Program - Qiskit
# ... using circuit method 1
# ... execution starting at Aug 04, 2022 16:09:19 UTC
# No credentials for IBMQ backend found.  Using the simulator instead.
# ************
# Executing [1] circuits with num_qubits = 4
#   ... performing dynamic decoupling.
# ERROR: Failed to execute circuit 4 0
# ... exception = 'NoneType' object has no attribute '_gates'
# ... execution complete at Aug 04, 2022 16:09:19 UTC in 0.34 secs
#
# Sample Circuit:
#          ┌─────┐┌────────────────────┐┌────────────────────┐»
# q3969_0: ┤0    ├┤0                   ├┤0                   ├»
#          │     ││                    ││                    │»
# q3969_1: ┤1    ├┤1                   ├┤1                   ├»
#          │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
# q3969_2: ┤2    ├┤2                   ├┤2                   ├»
#          │     ││                    ││                    │»
# q3969_3: ┤3    ├┤3                   ├┤3                   ├»
#          └─────┘└────────────────────┘└────────────────────┘»
#  meas: 4/═══════════════════════════════════════════════════»
#                                                             »
# «         ┌──────────────────────────┐ ░ ┌─┐
# «q3969_0: ┤0                         ├─░─┤M├─────────
# «         │                          │ ░ └╥┘┌─┐
# «q3969_1: ┤1                         ├─░──╫─┤M├──────
# «         │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «q3969_2: ┤2                         ├─░──╫──╫─┤M├───
# «         │                          │ ░  ║  ║ └╥┘┌─┐
# «q3969_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «         └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# « meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                         0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#      ┌──────────────────────────────────────────────────────────────────────┐
# q_0: ┤0                                                                     ├
#      │                                                                      │
# q_1: ┤1                                                                     ├
#      │  exp(-it (YXXX + XYXX + XXYX + YYYX + XXXY + YYXY + YXYY + XYYY))(1) │
# q_2: ┤2                                                                     ├
#      │                                                                      │
# q_3: ┤3                                                                     ├
#      └──────────────────────────────────────────────────────────────────────┘
#
# Benchmark Results - VQE Simulation (1) - Qiskit
#      ****** NO RESULTS ******

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding Algorithm Benchmark - Qiskit
# ... using circuit method 1
# Max number of qubits 5 is too low to run method 1 of Shor's Order Finding

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding Algorithm Benchmark - Qiskit
# ... using circuit method 2
# Max number of qubits 5 is too low to run method 2 of Shor's Order Finding

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 64
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
